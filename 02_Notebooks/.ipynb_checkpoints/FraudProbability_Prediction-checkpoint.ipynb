# %% [markdown]
# ## INSURANCE CLAIMS FRAUD PREDICTION
#
# Whether internal or external, there are a wide variety of threats posed to enterprises across multiple industries.  The most difficult threat to diagnose & address, however, is fraud.  Insurance frauds is one of the costliest white-collar crimes and accounts for huge losses every year.
#
# This notebook walks through how we can cut down on some of those losses by identifying the potential frauds upfront and flagging them for investigation. We use various machine and deep learning algorithms in order to conclusively extract the potency of fraud for a particular insurance claim.

# %% [markdown]
# ### Table of Contents
#
# - <a href="#dsp">The Data Science Process</a>
# - <a href="#step1">Step 1: Understanding the data</a>
# - <a href="#step2">Step 2: Data Manipulation and Feature Engineering</a>
# - <a href="#dlp">Deep Learning Model Process</a>
# - <a href="#step3">Step 3: Model Building and Scoring</a>
# - <a href="#kta">Key Takeaways</a>
# - <a href="#con">Conclusion</a>

# %% [markdown]
# <a id="dsp"></a>
# ### The Data Science Process
#
# We follow the conventional data science process to deal with this prediction problem. We go from understanding the data to , to deriving new pieces of data, performing feature engineering and then creating and validating the machine learning models.
#
# <a id="step1"></a>
# #### Step 1: Understanding the data
#
# For this problem we had at our disposal, data such as – customer demographics, customer claim transactions, policy information, claim assessor notes and medical record of the claimants. The sample below shows a glimpse of that data.

# %%
# Importing required libraries
import pandas as pd

# Showing a glimpse of the raw data
pd.option_context('display.max_rows', None, 'display.max_columns', None)
pd.read_csv('../RawData.csv').head()
# Out:
#    Unnamed: 0  CLAIM_NUMBER  CUSTOMER_NUMBER CUSTOMER_DOB  AGE  \
# 0           0      80276966         73664289   1983-09-09   35
# 1           1      80276968         81866238   1966-02-20   52
# 2           2      80276970         80965085   1990-10-10   28
# 3           3      80276972         35716618   1958-10-20   60
# 4           4      80276972         35716618   1958-10-20   60
#
#   CUSTOMER_GENDER  POLICY_NUMBER PRODUCT_CODE  LIFE  RIDER    ...     \
# 0               F       72884683         HSR4     2      0    ...
# 1               F       73260777         HSR4     1      2    ...
# 2               F       73219282         HSR4     1      1    ...
# 3               F       71163928         HSR1     1      1    ...
# 4               F       71163928         HSR1     1      1    ...
#
#    REGISTRATION_DT     FAMOUT Occupation_Code Marrige_Code Is_PO  CURRFROM  \
# 0       2015-08-03  1200000.0            1078            M     0  20180202
# ...

# %% [markdown]
# <a id="step2"></a>
# #### Step 2: Data Manipulation and Feature Engineering
#
# Once we have understood and have had a glimpse of all the data elements, the next part of the process is to be able to quickly build up dervied data elements and features and validate them through the process of feature engineering.
#
# One of the steps we did as part of the process was to take care of imbalanced data by performing synthetic sampling to ensure that there some level of balance is established between the fraud and non-fraud cases.
#
# As part of this case, from the raw data, we derive many features such as:
#
# ***Average value of all previous claims, Average claim confirmation time, Time till policy expiration, Rejected Claim Ratio, Total Claims till date, Time since last claim and others similar in nature.***

# %% [markdown]
# Let us have a glimpse of the data once we have derived the features and then see how we can gauge which features are important to ys and which are not.

# %%
feat_df = pd.read_csv('../features.csv', index_col=0)
feat_df.head() # Showing the features derived from the data
# Out:
#      AVG_CLAIM_VALUE    CCDATE  CLAIM_NUMBER  CLAIM_TYPE_CODE  COVERAGE  \
# AGE
# 35         1200000.0  20130123      80276966                2         1
# 52         1200000.0  20141224      80276968                2         0
# 28         2000000.0  20141030      80276970                2         0
# 28         1900000.0  20141030      80321381                2         0
# 60         1000000.0  20040701      80276972                2         0
#
#      CURRFROM    CURRTO CUSTOMER_DOB  CUSTOMER_GENDER  CUSTOMER_NUMBER  \
# AGE
# 35   20180202  99999999     9/9/1983                0         73664289
# 52   20180328  99999999    2/20/1966                0         81866238
# 28   20161109  99999999   10/10/1990                0         80965085
# 28   20161109  99999999   10/10/1990                0         80965085
# 60   20171220  99999999   10/20/1958                0         35716618
#
#          ...       PREMIUM  PRODUCT_CODE  REGISTRATION_DT  REJECT_CODE  \
# AGE      ...
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

def randForest(feat_df):

    # Drop columns not used for machine learning
    feat_df = feat_df.drop(['CUSTOMER_NUMBER', 'CUSTOMER_DOB', 'CLAIM_NUMBER', 'POLICY_NUMBER',
                                    'CURRFROM','CURRTO','STATDATE',
                                        'OCCDATE','CCDATE'], axis=1)
    inputs = 19

    # Re-arrange columns
    cols = list(feat_df.columns.values) #Make a list of all of the columns in the df
    cols.pop(cols.index('REJECT_CODE')) #Remove b from list
    #feat_df = feat_df[cols+['REJECT_CODE']] #Create new dataframe with columns in the order you want

    feature = np.array(feat_df.values[:,0:inputs])
    label = np.array(feat_df.values[:,-1])

    # RandomForest to calculate the importance of the features
    # Create decision tree classifer object
    clf = RandomForestClassifier(random_state=0, n_jobs=-1)
    inputs = 19

    # Train model
    model = clf.fit(feature, label)
    # Calculate feature importances
    importances = model.feature_importances_

    # Sort feature importances in descending order
    indices = np.argsort(importances)[::-1]

    # Rearrange feature names so they match the sorted feature importances
    names = [feat_df.columns[i] for i in indices]

    # Create plot
    plt.figure(num=None, figsize=(15, 4), dpi=80, facecolor='w', edgecolor='k')

    # Create plot title
    plt.title("Feature Importance")

    # Add bars
    plt.bar(range(feature.shape[1]), importances[indices])

    # Add feature names as x-axis labels
    plt.xticks(range(feature.shape[1]), names, rotation=90)

    # Show plot
    plt.show()

    return True

feat_df = feat_df.dropna()
randForest(feat_df)
# Out:
# True

# %% [markdown]
# The above graph shows the importance levels of the features in decreasing order. From this we can determine which features are important from the business and model perspective.
#
# *For example, Average Claim Value is more importance than Coverage or Rider.*

# %% [markdown]
# <a id="dlp"></a>
# #### Deep Learning Model Process

# %% [markdown]
# Deep learning is a broader class of machine learning in which the methods are based on learning data representation rather than task specific algorithms. Fraud is highly based on certain patterns and anomalies observed within the data. This along with the huge volume of transaction data associated calls for a methodology which can deal with the data volume, class imbalance and help learn patterns associated with fraud easily and also be able to adapt over time.|

# %% [markdown]
# <a id="step3"></a>
# #### Step 3: Model building and scoring
#
# Once, we have determined the features the next step is to build a deep learning model, validate it and then use it for scoring and determining potential fraud.
#
# For this notebook, due to time complexity, we will skip the model building and validation bit and show you how the scoring is done. In case you would like to know more about how the model is built, please do [Contact Us](www.justanalytics.com)

# %%
from datetime import datetime
import json
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.models import model_from_json

def modelScoreBatch(feat_data):

    '''
    Takes one argument: Processed DataFrame: feat_data
    Returns output dataframe

    Deep Learning Model Details:
    Inputs (Features): 18
    Outputs: 1

    '''
    #try:

    feat_data = feat_data.drop(['CUSTOMER_NUMBER', 'CUSTOMER_DOB', 'CLAIM_NUMBER',                                              'POLICY_NUMBER','CURRFROM','CURRTO','STATDATE',
                                        'OCCDATE','CCDATE'], axis=1)
    inputs = 19

    # Re-arrange columns
    cols = list(feat_data.columns.values) #Make a list of all of the columns in the df
    cols.pop(cols.index('REJECT_CODE')) #Remove b from list
    feat_data = feat_data[cols+['REJECT_CODE']] #Create new dataframe with columns in the order you want

    # Machine Learning Implementation starts here
    feat_data.sort_values(by='REJECT_CODE', ascending=False, inplace=True)

    feature = np.array(feat_data.values[:,0:inputs])
    label = np.array(feat_data.values[:,-1])

    # Shuffle and split the data into train and test sets
    from sklearn.utils import shuffle
    shuffle_df = shuffle(feat_data, random_state=42)
    req_len = int(len(feat_data)*0.30)
    df_train = shuffle_df[0:req_len]
    df_test = shuffle_df[req_len:]
    #logger.info("Divided the data into training and test sets.")

    train_feature = np.array(df_train.values[:,0:inputs])
    train_label = np.array(df_train.values[:,-1])
    test_feature = np.array(df_test.values[:,0:inputs])
    test_label = np.array(df_test.values[:,-1])

    # Standardize the features for speeding up deep learning (MinMaxScaler)
    scaler = MinMaxScaler()
    scaler.fit(train_feature)
    train_feature_trans = scaler.transform(train_feature)
    test_feature_trans = scaler.transform(test_feature)

    # Load JSON and Create Model
    json_file = open('../claim_model.json', 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    loaded_model = model_from_json(loaded_model_json)

    # Load weights into new model
    loaded_model.load_weights("../claim_model.h5")
    print("Loaded model from disk")

    # Evaluate loaded model on test data
    loaded_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    prediction = loaded_model.predict_classes(test_feature_trans)
    prediction_probs = loaded_model.predict_proba(test_feature_trans)

    # Display Predicted Outputs
    df_ans = pd.DataFrame({'Real Class' :test_label})
    df_ans['Prediction'] = prediction
    df_ans['PredictionProbabilities'] = prediction_probs
    df_ans[df_ans['Real Class'] != df_ans['Prediction']]
    print(df_ans['Prediction'].value_counts())
    print(df_ans['Real Class'].value_counts())

    cols = ['Real_Class_1','Real_Class_0']
    rows = ['Prediction_1','Prediction_0']

    B1P1 = len(df_ans[(df_ans['Prediction'] == df_ans['Real Class']) & (df_ans['Real Class'] == 1)])
    B1P0 = len(df_ans[(df_ans['Prediction'] != df_ans['Real Class']) & (df_ans['Real Class'] == 1)])
    B0P1 = len(df_ans[(df_ans['Prediction'] != df_ans['Real Class']) & (df_ans['Real Class'] == 0)])
    B0P0 = len(df_ans[(df_ans['Prediction'] == df_ans['Real Class']) & (df_ans['Real Class'] == 0)])

    conf = np.array([[B1P1,B0P1],[B1P0,B0P0]])
    df_cm = pd.DataFrame(conf, columns = [i for i in cols], index = [i for i in rows])

    f, ax= plt.subplots(figsize = (10, 5))
    sns.heatmap(df_cm, annot=True, ax=ax, fmt='d')
    ax.xaxis.set_ticks_position('top')

    # Joining the two dataframes and populating a final CSV
    test_cols = df_test.columns
    test_cols = list(test_cols)
    test_cols.append('Prediction')
    test_cols.append('PredictionProbabilities')
    df_test.reset_index(drop=True, inplace=True)
    df_ans.reset_index(drop=True, inplace=True)
    final_merged_df = pd.concat([df_test, df_ans['Prediction'], df_ans['PredictionProbabilities']], axis=1, sort=False,ignore_index = True)
    final_merged_df.columns = test_cols
    return True

    #except Exception as e:
    #    return False
feat_df = pd.read_csv('../features.csv')
feat_df = feat_df.dropna()
modelScoreBatch = modelScoreBatch(feat_df)
# Out:
# Loaded model from disk
# 1    38956
# 0    24101
# Name: Prediction, dtype: int64
# 1.0    32925
# 0.0    30132
# Name: Real Class, dtype: int64

# %% [markdown]
# The above code picks up a trained model and scores using the same.
#
# From the above result, we can see that we have around a **70% accuracy** on the predictions of possible frauds. For more information on the process of model training and how it works, please read our blog **here**.

# %% [markdown]
# <a id="kta"></a>
# ### Key Takeaways

# %% [markdown]
# - Feature Engineering helps identify all the important features which can be used to build the deep learning models and also help understand which are the variables that are important from the business perspective.
#
#
# - Deep Learning models work on imbalanced data more effectively than machine learning models. Since in this fraud case the data was quite imbalanced, deep learning models helped.
#
#
# - Being able to explain models is important for such cases. Reading through our blog post explains how that was achieved to a some scale.

# %% [markdown]
# <a id="con"></a>
# ### Conclusion

# %% [markdown]
# Fraud detection for health insurance is extremely important and necessary to reduce effort and have an early detection system to reduce delays and larger investigation cycles. To do this we use deep learning models which learn from millions of historical customer transactions.
